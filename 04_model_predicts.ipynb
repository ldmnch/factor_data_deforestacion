# %%
from sklearn.metrics import classification_report
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, KFold
from joblib import dump, load
import geopandas as gpd
import xgboost as xgb
import numpy as np

# %%
pipe_rf = load('./models/cv_rf.joblib') 
pipe_lr = load('./models/cv_lr.joblib') 
pipe_xgb = load('./models/cv_xgb.joblib')

# %%
train = gpd.read_file( "./data/train_data_final.geojson")
test =  gpd.read_file("./data/test_data_final.geojson")

# %%
X = train.loc[:,'NDVI_2000':'NDVI_2019']
y = train['label_0']
X_test = test.loc[:,'NDVI_2000':'NDVI_2019']

# %%
best_model_rf = pipe_rf.best_estimator_
best_model_lr = pipe_lr.best_estimator_
best_model_xgb = pipe_xgb.best_estimator_

# %%
print("Classification report de RF")
print(classification_report(test.label_0,best_model_rf.predict(X_test)))
print("\n")
print("Classification report de reg logística")
print(classification_report(test.label_0,best_model_lr.predict(X_test)))
print("\n")
print("Classification report de XGBoost")
print(classification_report(test.label_0,best_model_xgb.predict(X_test)))
print("\n")
# Out:
# Classification report de RF
#               precision    recall  f1-score   support
#
#            0       0.72      0.59      0.65       877
#            1       0.87      0.91      0.89       900
#            2       0.71      0.80      0.75       859
#
#     accuracy                           0.77      2636
#    macro avg       0.76      0.77      0.76      2636
# weighted avg       0.77      0.77      0.76      2636
#
#
#
# Classification report de reg logística
#               precision    recall  f1-score   support
#
#            0       0.55      0.49      0.52       877
#            1       0.76      0.77      0.77       900
#            2       0.67      0.74      0.70       859
#
#     accuracy                           0.67      2636
#    macro avg       0.66      0.67      0.66      2636
# weighted avg       0.66      0.67      0.66      2636
#
#
#
# Classification report de XGBoost
#               precision    recall  f1-score   support
#
#            0       0.67      0.61      0.64       877
#            1       0.88      0.89      0.88       900
#            2       0.69      0.75      0.72       859
#
#     accuracy                           0.75      2636
#    macro avg       0.75      0.75      0.75      2636
# weighted avg       0.75      0.75      0.75      2636

# %%
test['predictions_rf'] = best_model_rf.predict(X_test)
test['predictions_lr'] = best_model_lr.predict(X_test)
test['predictions_xgb'] = best_model_xgb.predict(X_test)

# %%
test
# Out:
#         id_0  label_0  NDVI_2000  NDVI_2001  NDVI_2002  NDVI_2004  NDVI_2005  \
# 0        0_0        1   0.000023   0.000036   0.000042   0.000045   0.000046
# 1        1_0        1   0.000026   0.000042   0.000047   0.000048   0.000041
# 2        2_0        1   0.000048   0.000045   0.000050   0.000056   0.000053
# 3        3_0        1   0.000025   0.000038   0.000043   0.000044   0.000041
# 4        4_0        1   0.000037   0.000039   0.000043   0.000040   0.000037
# ...      ...      ...        ...        ...        ...        ...        ...
# 2631  2695_0        2   0.000019   0.000030   0.000036   0.000034   0.000035
# 2632  2696_0        2   0.000027   0.000024   0.000032   0.000033   0.000032
# 2633  2697_0        2   0.000036   0.000036   0.000037   0.000036   0.000036
# 2634  2698_0        2   0.000037   0.000037   0.000041   0.000031   0.000034
# 2635  2699_0        2   0.000025   0.000031   0.000025   0.000030   0.000026
#
#       NDVI_2006  NDVI_2007  NDVI_2008  ...  NDVI_2014  NDVI_2015  NDVI_2016  \
# 0      0.000045   0.000038   0.000044  ...   0.000028   0.000025   0.000039
# 1      0.000045   0.000044   0.000050  ...   0.000033   0.000029   0.000042
# 2      0.000053   0.000050   0.000052  ...   0.000043   0.000040   0.000054
# 3      0.000050   0.000043   0.000045  ...   0.000043   0.000026   0.000043
# 4      0.000035   0.000034   0.000034  ...   0.000045   0.000037   0.000038
# ...         ...        ...        ...  ...        ...        ...        ...
# 2631   0.000034   0.000032   0.000031  ...   0.000022   0.000026   0.000036
# 2632   0.000033   0.000030   0.000031  ...   0.000035   0.000027   0.000025
# 2633   0.000038   0.000041   0.000041  ...   0.000038   0.000038   0.000040
# 2634   0.000029   0.000026   0.000024  ...   0.000031   0.000035   0.000035
# 2635   0.000025   0.000024   0.000025  ...   0.000028   0.000030   0.000030
#
#       NDVI_2017  NDVI_2018  NDVI_2019                     geometry  \
# 0      0.000037   0.000036   0.000040  POINT (-63.00671 -25.26624)
# 1      0.000036   0.000039   0.000038  POINT (-62.83379 -24.92263)
# 2      0.000051   0.000046   0.000037  POINT (-60.88444 -24.20174)
# 3      0.000043   0.000043   0.000040  POINT (-63.72985 -27.49855)
# 4      0.000038   0.000035   0.000041  POINT (-62.48569 -28.26212)
# ...         ...        ...        ...                          ...
# 2631   0.000036   0.000025   0.000032  POINT (-62.74395 -22.75545)
# 2632   0.000034   0.000030   0.000034  POINT (-65.92174 -28.27560)
# 2633   0.000049   0.000040   0.000037  POINT (-66.76841 -33.28820)
# 2634   0.000032   0.000034   0.000037  POINT (-62.35319 -28.85950)
# 2635   0.000027   0.000026   0.000030  POINT (-64.33397 -31.95195)
#
#       predictions_rf  predictions_lr  predictions_xgb
# 0                  1               1                1
# 1                  1               1                1
# 2                  1               1                1
# 3                  1               1                1
# 4                  1               0                2
# ...              ...             ...              ...
# 2631               0               0                0
# 2632               2               0                2
# 2633               0               0                0
# 2634               2               2                2
# 2635               2               2                2
#
# [2636 rows x 25 columns]

# %%
#test.to_file("data/test_predictions.geojson", driver='GeoJSON')
#Para GEE en .shp
test.to_file("data/preds/test_predictions.shp")
# Out:
# /tmp/ipykernel_4630/1963993009.py:3: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   test.to_file("data/preds/test_predictions.shp")
