# %%
import ee 
from functions import geojson2FeatureCollection, exporto_modis, proc_data, run_predictions

# %%
ee.Authenticate()
ee.Initialize()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=VuviftYeYjE-ryR1CVJongy4-7UFPpE5K7vnukI-NJc&tc=yOQ3yvGCUX39NweTOH76hOQ44ZNXLSvYYKjkDmrRG3k&cc=pLhWE763PO64jiSsFC5e2LS1xDj8xzJGwqrAN3bTDb0>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=VuviftYeYjE-ryR1CVJongy4-7UFPpE5K7vnukI-NJc&tc=yOQ3yvGCUX39NweTOH76hOQ44ZNXLSvYYKjkDmrRG3k&cc=pLhWE763PO64jiSsFC5e2LS1xDj8xzJGwqrAN3bTDb0</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code:  4/1AWtgzh7JFdvi8as4kTb3-tO1UMbLn8_oUF5d7SS2cDj4M8j7VWSpy88rfwI
# Successfully saved authorization token.

# %%
region = ee.FeatureCollection("projects/ee-ldb-deforestacion-montes/assets/regiones_chaco/controles_german")
region = region.filter("id == 3")

# %%
for i in [0, 3, 4, 7, 10, 13, 16, 18]:
    
    exporto_modis(region,
                rango_anios = range(i, i+3, 1),
                file_sufix = str(i)+"-"+str(i+2))
# Out:
# Exporto MODIS 0-2
# Exporto MODIS 3-5
# Exporto MODIS 4-6
# Exporto MODIS 7-9
# Exporto MODIS 10-12
# Exporto MODIS 13-15
# Exporto MODIS 16-18
# Exporto MODIS 18-20

# %%
proc_data()
# Out:
# ['./data/test_region/ndvi_model_4-6.geojson', './data/test_region/ndvi_model_7-9.geojson', './data/test_region/ndvi_model_16-18.geojson', './data/test_region/ndvi_model_0-2.geojson', './data/test_region/ndvi_model_10-12.geojson', './data/test_region/ndvi_model_3-5.geojson', './data/test_region/ndvi_model_13-15.geojson', './data/test_region/ndvi_model_18-20.geojson']

# %%
predicted_data = run_predictions('./data/test_region/data_final.geojson',
               model = "RF")
# Out:
#         NDVI_2000  NDVI_2001  NDVI_2002  NDVI_2003  NDVI_2004  NDVI_2005  \
# 0        0.304150   0.255779   0.293928   0.285096   0.236429   0.330171
# 1        0.314196   0.266368   0.308866   0.297549   0.250157   0.346021
# 2        0.314196   0.266368   0.308866   0.297549   0.250157   0.346021
# 3        0.329997   0.298396   0.355508   0.335648   0.282824   0.355955
# 4        0.329997   0.298396   0.355508   0.335648   0.282824   0.355955
# ...           ...        ...        ...        ...        ...        ...
# 156642   0.234806   0.417106   0.427313   0.463073   0.433355   0.382567
# 156643   0.221949   0.434410   0.437924   0.463672   0.433001   0.387853
# 156644   0.221949   0.434410   0.437924   0.463672   0.433001   0.387853
# 156645   0.215117   0.410455   0.443597   0.482398   0.441239   0.398328
# 156646   0.215117   0.410455   0.443597   0.482398   0.441239   0.398328
#
#         NDVI_2006  NDVI_2007  NDVI_2008  NDVI_2009  ...  NDVI_2014  NDVI_2015  \
# 0        0.306754   0.240447   0.292180   0.220936  ...   0.246842   0.248425
# 1        0.322430   0.256344   0.298520   0.227859  ...   0.258119   0.256984
# 2        0.322430   0.256344   0.298520   0.227859  ...   0.258119   0.256984
# 3        0.341481   0.276273   0.318067   0.247868  ...   0.276600   0.259326
# 4        0.341481   0.276273   0.318067   0.247868  ...   0.276600   0.259326
# ...           ...        ...        ...        ...  ...        ...        ...
# 156642   0.400104   0.376380   0.427607   0.425903  ...   0.301424   0.181316
# 156643   0.396965   0.373892   0.424071   0.426626  ...   0.302538   0.204832
# 156644   0.396965   0.373892   0.424071   0.426626  ...   0.302538   0.204832
# 156645   0.402847   0.386384   0.425551   0.440888  ...   0.304596   0.203268
# 156646   0.402847   0.386384   0.425551   0.440888  ...   0.304596   0.203268
#
#         NDVI_2016  NDVI_2017  NDVI_2018  NDVI_2019  NDVI_2020  \
# 0        0.243688   0.236194   0.251965   0.236579   0.224555
# 1        0.244026   0.238696   0.251608   0.240925   0.220857
# 2        0.244026   0.238696   0.251608   0.240925   0.220857
# 3        0.253619   0.245966   0.259379   0.252055   0.229248
# 4        0.253619   0.245966   0.259379   0.252055   0.229248
# ...           ...        ...        ...        ...        ...
# 156642   0.429970   0.463554   0.408837   0.444286   0.463479
# 156643   0.451886   0.419936   0.408691   0.446279   0.466577
# 156644   0.451886   0.419936   0.408691   0.446279   0.466577
# 156645   0.413182   0.392415   0.383270   0.445720   0.458386
# 156646   0.413182   0.392415   0.383270   0.445720   0.458386
#
#                                  id                     geometry  RF_pred
# 0            00000000000000000002_0  POINT (-62.23191 -26.54634)        2
# 1            00000000000000000002_1  POINT (-62.22967 -26.54634)        2
# 2            00000000000000000002_2  POINT (-62.22742 -26.54634)        2
# 3            00000000000000000002_3  POINT (-62.22518 -26.54634)        2
# 4            00000000000000000002_4  POINT (-62.22293 -26.54634)        2
# ...                             ...                          ...      ...
# 156642  00000000000000000002_156642  POINT (-63.17515 -25.73561)        0
# 156643  00000000000000000002_156643  POINT (-63.17290 -25.73561)        0
# 156644  00000000000000000002_156644  POINT (-63.17065 -25.73561)        0
# 156645  00000000000000000002_156645  POINT (-63.16841 -25.73561)        0
# 156646  00000000000000000002_156646  POINT (-63.16616 -25.73561)        0
#
# [156647 rows x 24 columns]
